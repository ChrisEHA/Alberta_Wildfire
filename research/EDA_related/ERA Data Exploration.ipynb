# %% [markdown]
# Data import check

# %%
conda env create -f environment.yml
conda activate era5-docs

import fsspec

fs = fsspec.filesystem('gs')
fs.ls('gs://gcp-public-data-arco-era5/co/')
# Out:
#   File "<ipython-input-3-9acffcf980cc>", line 1
#     conda env create -f environment.yml
#           ^
# SyntaxError: invalid syntax
